# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os
print(os.getcwd())
for dirname, _, filenames in os.walk(r"C:\git\machine learning\house-price-prediction\data\raw"):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# C:\git\machine learning\house-price-prediction\notebooks
# C:\git\machine learning\house-price-prediction\data\raw\AmesHousing.csv

# %%
pd.set_option('display.max_columns', None)
#reading the csv file
df = pd.read_csv(r"C:\git\machine learning\house-price-prediction\data\raw\AmesHousing.csv")
# Displaying the first five rows
df.head()
# Out:
#    Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      1  526301100           20        RL         141.0     31770   Pave
# 1      2  526350040           20        RH          80.0     11622   Pave
# 2      3  526351010           20        RL          81.0     14267   Pave
# 3      4  526353030           20        RL          93.0     11160   Pave
# 4      5  527105010           60        RL          74.0     13830   Pave
#
#   Alley Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0   NaN       IR1          Lvl    AllPub     Corner        Gtl        NAmes
# 1   NaN       Reg          Lvl    AllPub     Inside        Gtl        NAmes
# 2   NaN       IR1          Lvl    AllPub     Corner        Gtl        NAmes
# 3   NaN       Reg          Lvl    AllPub     Corner        Gtl        NAmes
# 4   NaN       IR1          Lvl    AllPub     Inside        Gtl      Gilbert
#
# ...

# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
# View column types and non-null counts
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2930 entries, 0 to 2929
# Data columns (total 82 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Order            2930 non-null   int64
#  1   PID              2930 non-null   int64
#  2   MS SubClass      2930 non-null   int64
#  3   MS Zoning        2930 non-null   object
#  4   Lot Frontage     2440 non-null   float64
#  5   Lot Area         2930 non-null   int64
#  6   Street           2930 non-null   object
#  7   Alley            198 non-null    object
#  8   Lot Shape        2930 non-null   object
#  9   Land Contour     2930 non-null   object
#  10  Utilities        2930 non-null   object
#  11  Lot Config       2930 non-null   object
#  12  Land Slope       2930 non-null   object
#  13  Neighborhood     2930 non-null   object
#  14  Condition 1      2930 non-null   object
#  15  Condition 2      2930 non-null   object
# ...

# %%
# Descriptive statistics for numerical columns
df.describe().T
# Out:
#                   count          mean           std          min  \
# Order            2930.0  1.465500e+03  8.459625e+02          1.0
# PID              2930.0  7.144645e+08  1.887308e+08  526301100.0
# MS SubClass      2930.0  5.738737e+01  4.263802e+01         20.0
# Lot Frontage     2440.0  6.922459e+01  2.336533e+01         21.0
# Lot Area         2930.0  1.014792e+04  7.880018e+03       1300.0
# Overall Qual     2930.0  6.094881e+00  1.411026e+00          1.0
# Overall Cond     2930.0  5.563140e+00  1.111537e+00          1.0
# Year Built       2930.0  1.971356e+03  3.024536e+01       1872.0
# Year Remod/Add   2930.0  1.984267e+03  2.086029e+01       1950.0
# Mas Vnr Area     2907.0  1.018968e+02  1.791126e+02          0.0
# BsmtFin SF 1     2929.0  4.426296e+02  4.555908e+02          0.0
# BsmtFin SF 2     2929.0  4.972243e+01  1.691685e+02          0.0
# Bsmt Unf SF      2929.0  5.592625e+02  4.394942e+02          0.0
# ...

# %%
# Total missing values per column
df.isnull().sum().sort_values(ascending=False).head(20)
# Out:
# Pool QC           2917
# Misc Feature      2824
# Alley             2732
# Fence             2358
# Mas Vnr Type      1775
# Fireplace Qu      1422
# Lot Frontage       490
# Garage Qual        159
# Garage Yr Blt      159
# Garage Cond        159
# Garage Finish      159
# Garage Type        157
# Bsmt Exposure       83
# BsmtFin Type 2      81
# Bsmt Qual           80
# Bsmt Cond           80
# BsmtFin Type 1      80
# Mas Vnr Area        23
# Bsmt Full Bath       2
# Bsmt Half Bath       2
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(15749)

# %%
df.sample(10, random_state=42)
# Out:
#       Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 1357   1358  903427090           70        RM           NaN      5100   Pave
# 2367   2368  527450460          160        RM          21.0      1890   Pave
# 2822   2823  908128100           60        RL          62.0      7162   Pave
# 2126   2127  907135180           20        RL          60.0      8070   Pave
# 1544   1545  910200080           30        RM          50.0      7000   Pave
# 2415   2416  528221010           20        RL         102.0     11660   Pave
# 2227   2228  909455060          120        RM          35.0      3907   Pave
# 410     411  527453060          160        RL          24.0      2280   Pave
# 761     762  904100190           20        RL          50.0      4280   Pave
# 436     437  528118060           60        RL          59.0     23303   Pave
#
#      Alley Lot Shape Land Contour Utilities Lot Config Land Slope  \
# ...

# %%
#here i was surprized by many thingslets see we have pid in 10 digit
"""  alley mostly not available, mas vnr type is also fishy,
mas vnr area is 0 in the row  mass vnr type is NAN, bsmt is mostly 0 and low qualfin sf is also zero. anfd the last few aprt are most nul vaules."""
# Out:
# '  alley mostly not available, mas vnr type is also fishy,\nmas vnr area is 0 in the row  mass vnr type is NAN, bsmt is mostly 0 and low qualfin sf is also zero. anfd the last few aprt are most nul vaules.'

# %%
df.dtypes.value_counts()
# Out:
# object     43
# int64      28
# float64    11
# Name: count, dtype: int64

# %%
df['SalePrice'].describe()
# Out:
# count      2930.000000
# mean     180796.060068
# std       79886.692357
# min       12789.000000
# 25%      129500.000000
# 50%      160000.000000
# 75%      213500.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
"""here the data is right skewed"""
# Out:
# 'here the data is right skewed'

# %%
df.describe()
# Out:
#             Order           PID  MS SubClass  Lot Frontage       Lot Area  \
# count  2930.00000  2.930000e+03  2930.000000   2440.000000    2930.000000
# mean   1465.50000  7.144645e+08    57.387372     69.224590   10147.921843
# std     845.96247  1.887308e+08    42.638025     23.365335    7880.017759
# min       1.00000  5.263011e+08    20.000000     21.000000    1300.000000
# 25%     733.25000  5.284770e+08    20.000000     58.000000    7440.250000
# 50%    1465.50000  5.354536e+08    50.000000     68.000000    9436.500000
# 75%    2197.75000  9.071811e+08    70.000000     80.000000   11555.250000
# max    2930.00000  1.007100e+09   190.000000    313.000000  215245.000000
#
#        Overall Qual  Overall Cond   Year Built  Year Remod/Add  Mas Vnr Area  \
# count   2930.000000   2930.000000  2930.000000     2930.000000   2907.000000
# mean       6.094881      5.563140  1971.356314     1984.266553    101.896801
# ...

# %%
"""ID columns (2 columns: Order, PID) is not importtant this are useless
Bucket 3 — Numerical features (columns that are genuinely quantities)

These split into two sub-types:

Continuous — can take any value in a range. Lot Area can be 6,000 or 6,247 or 10,834. Gr Liv Area (above-grade living area in sq ft) is the same.
These are real measurements.Discrete — can only be whole numbers with a limited set of values. 
Full Bath is 0, 1, 2, or 3. Fireplaces is 0, 1, 2, or 3. Bedroom AbvGr is 0 through 8. 
These count things."""
# Out:
# 'ID columns (2 columns: Order, PID) is not importtant this are useless\nBucket 3 — Numerical features (columns that are genuinely quantities)\n\nThese split into two sub-types:\n\nContinuous — can take any value in a range. Lot Area can be 6,000 or 6,247 or 10,834. Gr Liv Area (above-grade living area in sq ft) is the same.\nThese are real measurements.Discrete — can only be whole numbers with a limited set of values. \nFull Bath is 0, 1, 2, or 3. Fireplaces is 0, 1, 2, or 3. Bedroom AbvGr is 0 through 8. \nThese count things.'

# %%
"""
Definitely drop (clear cut):

Order - ID column
PID - ID column
Utilities - 99.9% same value (AllPub)
Street - 99.6% same value (Pave)
Pool QC - 99.6% missing (and Pool Area already captures this)
Misc Feature - 96.4% missing (and Misc Val already captures this)
Low Qual Fin SF - 98.6% zeros
3Ssn Porch - 98.7% zeros
Condition 2 - 99.0% same value
Roof Matl - 98.5% same value
Pool Area - 99.6% zeros (same as Pool QC)
Misc Val - 96.5% zeros
Probably drop (debatable):

13. Bsmt Half Bath - 94.0% zeros

14. Kitchen AbvGr - 95.4% are value 1 (but the few that differ might matter)

15. Heating - 98.5% same value

16. Alley - 93.2% missing but could be binary

17. Fence - 80.5% missing
Keep but note issues:

Garage Yr Blt - data entry error (max 2207), keep but fix the error
Central Air - 93.3% Y, but still might have predictive power as binary
Yr Sold - only 5 unique values (2006-2010), debatable
"""
# Out:
# '\nDefinitely drop (clear cut):\n\nOrder - ID column\nPID - ID column\nUtilities - 99.9% same value (AllPub)\nStreet - 99.6% same value (Pave)\nPool QC - 99.6% missing (and Pool Area already captures this)\nMisc Feature - 96.4% missing (and Misc Val already captures this)\nLow Qual Fin SF - 98.6% zeros\n3Ssn Porch - 98.7% zeros\nCondition 2 - 99.0% same value\nRoof Matl - 98.5% same value\nPool Area - 99.6% zeros (same as Pool QC)\nMisc Val - 96.5% zeros\n'
